# %%
import pandas as pd

df1= pd.read_csv('twse_monthly_revenue_mock_200.csv')

df2=df1[['出表日期', '資料年月', '公司代號', '公司名稱','產業別']]
df2.shape
df2.dtypes
df2.size
df2.loc[:5]
df2.iloc[-5:]
df2.iloc[-5:][['公司代號', '公司名稱']]
# Out:
#      公司代號     公司名稱
# 195  1295  測試公司196
# 196  1296  測試公司197
# 197  1297  測試公司198
# 198  1298  測試公司199
# 199  1299  測試公司200
