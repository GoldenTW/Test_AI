# %%
#自訂Clase

class Person:  
    def __init__(self,name:str,age:int):
        self.name = name
        self.age = age

# %%
p1= Person("robert","35")
print(p1.name)
print(p1.age)
# Out:
# robert
# 35

# %%
p2= Person(age=50,name="Golden")
print(p2.name)
print(p2.age)
# Out:
# Golden
# 50
