# %%
# list 轉換為numpy的操作
import numpy as np

array_1 = np.array([1,3,5,7,9])

array_2 = np.array([[1,3,5,7,9],[2,4,6,8,10]])
array_2.ndim
array_2.dtype
array_2.size
array_2.shape
# Out:
# (2, 5)

# %%
np.zeros((3,6))
np.empty((2,3,2))
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])
