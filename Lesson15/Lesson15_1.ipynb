# %%
# list 轉換為numpy的操作
import numpy as np

array_1 = np.array([1,3,5,7,9])

array_2 = np.array([[1,3,5,7,9],[2,4,6,8,10]])
array_2.ndim
array_2.dtype
array_2.size
array_2.shape
# Out:
# (2, 5)

# %%
np.zeros((3,6))
np.empty((2,3,2))
np.arrange(15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 np.zeros((3,6))
#       2 np.empty((2,3,2))
# ----> 3 np.arrange(15)
#
# File ~/Desktop/AI分析/Python/Test_AI/.venv/lib/python3.11/site-packages/numpy/__init__.py:795, in __getattr__(attr)
#     792     import numpy.char as char
#     793     return char.chararray
# --> 795 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'arrange'
