# %%
import numpy as np
import pandas as pd

students = np.random.randint(50, high=101, size=(50, 5))
students_df = pd.DataFrame(students, index=[f"Student_{i}" for i in range(1,51)], columns=['Math', 'Science', 'English', 'History', 'Art'])
students_df
# Out:
#             Math  Science  English  History  Art
# Student_1     64       51       85       95   56
# Student_2     52       53       63       89   95
# Student_3     93       72       91       83   99
# Student_4     63       58       86       85   94
# Student_5    100       74       60       92   57
# Student_6     56       89       64       97   72
# Student_7     82       92       95       86   60
# Student_8     98       70      100       66   61
# Student_9     72       75       59       58   68
# Student_10    74       66       71       62   76
# Student_11    57       77       68       74   80
# Student_12    88       69       78       60   95
# Student_13    75       88       86       57   64
# Student_14    62       78       72       78   69
# Student_15    69       81       53       90   80
# Student_16    97       58       79       54   63
# Student_17    75       65       57       77   98
# Student_18    97       67       89       58   91
# ...

# %%
students_df.to_numpy()
# Out:
# array([[ 64,  51,  85,  95,  56],
#        [ 52,  53,  63,  89,  95],
#        [ 93,  72,  91,  83,  99],
#        [ 63,  58,  86,  85,  94],
#        [100,  74,  60,  92,  57],
#        [ 56,  89,  64,  97,  72],
#        [ 82,  92,  95,  86,  60],
#        [ 98,  70, 100,  66,  61],
#        [ 72,  75,  59,  58,  68],
#        [ 74,  66,  71,  62,  76],
#        [ 57,  77,  68,  74,  80],
#        [ 88,  69,  78,  60,  95],
#        [ 75,  88,  86,  57,  64],
#        [ 62,  78,  72,  78,  69],
#        [ 69,  81,  53,  90,  80],
#        [ 97,  58,  79,  54,  63],
#        [ 75,  65,  57,  77,  98],
#        [ 97,  67,  89,  58,  91],
#        [ 77,  53,  50,  94,  88],
#        [ 72,  93,  89,  76,  54],
#        [ 51,  95,  61,  53,  54],
#        [ 67,  71,  89,  83,  55],
#        [ 88,  69,  90,  73,  54],
#        [ 63,  71,  64,  98, 100],
#        [ 86,  58,  64,  74,  82],
#        [ 69,  92,  50,  74,  84],
#        [ 72,  68,  72, 100,  55],
# ...

# %%
# serious 

students_df['Math']
students_df['Science']

# dataframe的多欄位選取
students_df[['Math','Science']]
# Out:
#             Math  Science
# Student_1     64       51
# Student_2     52       53
# Student_3     93       72
# Student_4     63       58
# Student_5    100       74
# Student_6     56       89
# Student_7     82       92
# Student_8     98       70
# Student_9     72       75
# Student_10    74       66
# Student_11    57       77
# Student_12    88       69
# Student_13    75       88
# Student_14    62       78
# Student_15    69       81
# Student_16    97       58
# Student_17    75       65
# Student_18    97       67
# Student_19    77       53
# Student_20    72       93
# Student_21    51       95
# Student_22    67       71
# Student_23    88       69
# Student_24    63       71
# Student_25    86       58
# Student_26    69       92
# Student_27    72       68
# Student_28    77       90
# Student_29    73       73
# Student_30    70       70
# Student_31    71       50
# Student_32    61       64
# Student_33    70       68
# Student_34    60       68
# ...
