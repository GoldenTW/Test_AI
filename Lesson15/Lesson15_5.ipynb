# %%
import numpy as np
import pandas as pd

students = np.random.randint(50, high=101, size=(50, 5))
students_df = pd.DataFrame(students, index=[f"Student#{i}" for i in range(1,51)], columns=['Math', 'Science', 'English', 'History', 'Art'])
students_df
# Out:
#             Math  Science  English  History  Art
# Student#1     74       92       73       64   63
# Student#2     51       63      100       99   87
# Student#3     86       62       54       88   71
# Student#4     91       81       58       65   99
# Student#5     70       85       59       96   87
# Student#6     70       83       76       57   67
# Student#7     52       52       52       95   58
# Student#8     74       62       81       59   99
# Student#9     62       77       69       67   70
# Student#10    98       98       74       77   87
# Student#11    58       77       64       91   81
# Student#12    81       60       94       64   52
# Student#13    98       64       65       94   58
# Student#14    50       62       61       79   55
# Student#15    97       61       70       53   77
# Student#16    71       98       69       52   62
# Student#17    83       99       58       88   65
# Student#18    74       51       73       80   90
# ...

# %%
students_df.iloc[0]  #透過index位置選取第一位學生
# Out:
# Math       74
# Science    92
# English    73
# History    64
# Art        63
# Name: Student#1, dtype: int64

# %%
students_df.loc['Student#1'] #透過index名稱選取第一位學生
# Out:
# Math       74
# Science    92
# English    73
# History    64
# Art        63
# Name: Student#1, dtype: int64

# %%
students_df.loc[['Student#1','Student#2']]
# Out:
#            Math  Science  English  History  Art
# Student#1    74       92       73       64   63
# Student#2    51       63      100       99   87

# %%
students_df.loc[('Student#1','Student#2'), ['Math','Science']]
# Out:
#            Math  Science
# Student#1    74       92
# Student#2    51       63

# %%
students_df.iloc[:5, :2]
# Out:
#            Math  Science
# Student#1    74       92
# Student#2    51       63
# Student#3    86       62
# Student#4    91       81
# Student#5    70       85
