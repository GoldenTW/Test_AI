# %%
import pandas as pd

df1= pd.read_csv('twse_monthly_revenue_mock_200.csv')

df1
# Out:
#         出表日期   資料年月  公司代號     公司名稱    產業別  營業收入-當月營收  營業收入-上月營收  營業收入-去年當月營收  \
# 0    1110912  11108  1100    測試公司1    光電業     304759     318466       267547
# 1    1110912  11108  1101    測試公司2   半導體業    3759644    3663471      3596154
# 2    1110912  11108  1102    測試公司3   半導體業    5033473    4088464      3916409
# 3    1110912  11108  1103    測試公司4   半導體業    7462356    6628245      6826115
# 4    1110912  11108  1104    測試公司5   半導體業    1025358     866498      1160113
# ..       ...    ...   ...      ...    ...        ...        ...          ...
# 195  1110912  11108  1295  測試公司196    光電業    8611680    9894583      6390097
# 196  1110912  11108  1296  測試公司197  其他電子業    5908689    5678954      6795816
# 197  1110912  11108  1297  測試公司198   半導體業    6181398    6455822      7785126
# 198  1110912  11108  1298  測試公司199   水泥工業    2198044    1958192      1840165
# 199  1110912  11108  1299  測試公司200  其他電子業     622357     591797       710570
#
# ...

# %%
df1.iloc[0:5, 0:3]
# Out:
#       出表日期   資料年月  公司代號
# 0  1110912  11108  1100
# 1  1110912  11108  1101
# 2  1110912  11108  1102
# 3  1110912  11108  1103
# 4  1110912  11108  1104
