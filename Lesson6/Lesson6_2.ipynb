# %%
#沒有參數沒有傳出值

def sayhello():
    print("Hello Python!")  

sayhello()
# Out:
# Hello Python!

# %%
#有參數沒有傳出值

def sayhello(Name):
   print(f"你好!{Name}, 歡迎來到Python的世界!")  

sayhello("小明")
# Out:
# 你好!小明, 歡迎來到Python的世界!

# %%
#有參數有傳出值

def sayhello(Name):
    
   return f"你好!{Name}, 歡迎來到Python的世界!"  

print(sayhello("小明"))
# Out:
# 你好!小明, 歡迎來到Python的世界!

# %%
#計算BMI值

def calculate_bmi(weight, height):
    bmi = weight / ((height/100) ** 2)
    return round(bmi,2)


#分別顯示體重過輕、體重正常、體重過重、肥胖
def bmi_message(bmi):
    if bmi < 18.5:
        message="體重過輕"
    elif bmi >= 18.5 and bmi < 24:
        message="體重正常"
    elif bmi >= 24 and bmi < 27:
        message="體重過重"
    else:
        message="肥胖" 
    return message  

height = float(input("請輸入身高(公分):"))

weight = float(input("請輸入體重(公斤):"))
bmi = calculate_bmi(weight, height)
print(f"BMI值為:{round(bmi,2)}")
print(bmi_message(bmi))
# Out:
# BMI值為:20.28
# 體重正常
