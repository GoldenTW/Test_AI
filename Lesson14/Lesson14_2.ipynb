# %%
my_list = [1, 2, 3, 4, 5]

new_list = [x * 10 for x in my_list]

print(new_list)
new_list
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]

# %%
import numpy as np

my_array = np.array([1, 2, 3, 4, 5])
my_array *= 10
print(my_array)
my_array
# Out:
# [10 20 30 40 50]
# array([10, 20, 30, 40, 50])
