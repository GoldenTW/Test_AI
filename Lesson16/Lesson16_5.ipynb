# %%
import pandas as pd

dataFrame = pd.read_csv('world.csv')
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548751 entries, 0 to 548750
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              548751 non-null  int64
#  1   iso_code        524887 non-null  object
#  2   洲名              507679 non-null  object
#  3   國家              548751 non-null  object
#  4   日期              548751 non-null  object
#  5   總確診數            535599 non-null  float64
#  6   新增確診數           532023 non-null  float64
#  7   七天移動平均新增確診數     530814 non-null  float64
#  8   總死亡數            535599 non-null  float64
#  9   新增死亡數           532957 non-null  float64
#  10  七天移動平均新增死亡數     531745 non-null  float64
#  11  七天移動平均疫苗新增接種劑數  202840 non-null  float64
#  12  每百人接種疫苗劑數       83222 non-null   float64
#  13  每百人接種疫苗人數       79011 non-null   float64
#  14  疫情控管指數          202760 non-null  float64
#  15  總人口數            531268 non-null  float64
# ...

# %%
allDataFrame = dataFrame.reindex(columns=['洲名','國家', '日期','總確診數','新增確診數','總人口數','總死亡數'])
allDataFrame.head(10)
mask = allDataFrame["洲名"] == "Asia"
allDataFrame[mask]
# Out:
#           洲名           國家          日期     總確診數  新增確診數        總人口數    總死亡數
# 0       Asia  Afghanistan  2020-01-01      NaN    NaN  40578847.0     NaN
# 1       Asia  Afghanistan  2020-01-02      NaN    NaN  40578847.0     NaN
# 2       Asia  Afghanistan  2020-01-03      NaN    NaN  40578847.0     NaN
# 3       Asia  Afghanistan  2020-01-04      0.0    0.0  40578847.0     0.0
# 4       Asia  Afghanistan  2020-01-05      0.0    0.0  40578847.0     0.0
# ...      ...          ...         ...      ...    ...         ...     ...
# 544438  Asia        Yemen  2025-11-19  11945.0    0.0  38222878.0  2159.0
# 544439  Asia        Yemen  2025-11-20  11945.0    0.0  38222878.0  2159.0
# 544440  Asia        Yemen  2025-11-21  11945.0    0.0  38222878.0  2159.0
# 544441  Asia        Yemen  2025-11-22  11945.0    0.0  38222878.0  2159.0
# 544442  Asia        Yemen  2025-11-23  11945.0    0.0  38222878.0  2159.0
#
# [105624 rows x 7 columns]

# %%
#選取台灣的資料
mask = allDataFrame["國家"] == "Taiwan"
taiwanData = allDataFrame[mask]
taiwanData
# Out:
#           洲名      國家          日期  總確診數  新增確診數        總人口數  總死亡數
# 474651  Asia  Taiwan  2020-01-01   NaN    NaN  23420107.0   NaN
# 474652  Asia  Taiwan  2020-01-02   NaN    NaN  23420107.0   NaN
# 474653  Asia  Taiwan  2020-01-03   NaN    NaN  23420107.0   NaN
# 474654  Asia  Taiwan  2020-01-04   NaN    NaN  23420107.0   NaN
# 474655  Asia  Taiwan  2020-01-05   NaN    NaN  23420107.0   NaN
# ...      ...     ...         ...   ...    ...         ...   ...
# 476056  Asia  Taiwan  2025-08-31   NaN    NaN  23420107.0   NaN
# 476057  Asia  Taiwan  2025-09-30   NaN    NaN  23420107.0   NaN
# 476058  Asia  Taiwan  2025-10-31   NaN    NaN  23420107.0   NaN
# 476059  Asia  Taiwan  2025-11-30   NaN    NaN  23420107.0   NaN
# 476060  Asia  Taiwan  2025-12-31   NaN    NaN  23420107.0   NaN
#
# [1410 rows x 7 columns]

# %%
#台灣與日本的資料比較, 新增確診大於5000的資料
mask_taiwan = (allDataFrame["國家"] == "Taiwan") & (allDataFrame["新增確診數"] > 5000)
mask_japan = (allDataFrame["國家"] == "Japan") & (allDataFrame["新增確診數"] > 5000)
taiwan_japan_data = allDataFrame[mask_taiwan | mask_japan]
taiwan_japan_data
# Out:
#           洲名     國家          日期        總確診數    新增確診數         總人口數     總死亡數
# 239774  Asia  Japan  2021-01-01    238012.0   7708.0  124997585.0   3460.0
# 239779  Asia  Japan  2021-01-06    258393.0   6076.0  124997585.0   3719.0
# 239780  Asia  Japan  2021-01-07    265299.0   6906.0  124997585.0   3791.0
# 239781  Asia  Japan  2021-01-08    273154.0   7855.0  124997585.0   3857.0
# 239782  Asia  Japan  2021-01-09    280775.0   7621.0  124997585.0   3932.0
# ...      ...    ...         ...         ...      ...          ...      ...
# 240628  Asia  Japan  2023-05-05  33766957.0   7343.0  124997585.0  74633.0
# 240629  Asia  Japan  2023-05-06  33772764.0   5807.0  124997585.0  74645.0
# 240630  Asia  Japan  2023-05-07  33778993.0   6229.0  124997585.0  74654.0
# 240631  Asia  Japan  2023-05-08  33793429.0  14436.0  124997585.0  74669.0
# 240632  Asia  Japan  2023-05-09  33802739.0   9310.0  124997585.0  74669.0
#
# [552 rows x 7 columns]
