# %%
with open('assets/names.txt', 'r', encoding='utf-8') as f:
    content = f.read()

names_list = content.split(',')

print(names_list)
# Out:
# ['邱家綺\n洪思涵\n賴家恩\n周冠倫\n黃怡婷\n廖冠廷\n許惠如\n楊雅慧\n賴冠宇\n邱雅婷\n蔡冠廷\n黃雅筑\n張惠如\n許淑華\n黃佩珊\n賴欣樺\n洪俊榮\n郭柏叡\n許佩君\n周佳蓉\n邱彥廷\n黃佳穎\n廖家豪\n邱怡君\n謝俊宇\n鄭柏均\n陳雅文\n張偉倫\n謝家瑋\n賴佩芸\n張佩雯\n曾宥嘉\n吳家瑜\n蔡俊豪\n謝雅筑\n廖佩蓉\n鄭雅慧\n許俊毅\n林佩珊\n郭雅筑\n王志誠\n李俊維\n鄭惠如\n楊宥嘉\n邱冠中\n許佩蓉\n王俊維\n吳佳穎\n謝俊宏\n王欣穎\n鄭雅筑\n謝俊偉\n蔡志偉\n蔡欣樺\n王建宏\n楊志豪\n廖俊偉\n郭雅雯\n廖志偉\n謝淑娟\n洪冠霖\n許家恩\n張冠倫\n曾美玲\n謝雅婷\n曾冠瑋\n郭志偉\n許怡樺\n廖志明\n陳俊傑\n邱俊霖\n鄭家綸\n王俊榮\n楊嘉欣\n蔡俊宏\n黃家瑋\n黃佩雯\n許雅文\n洪志偉\n王怡婷\n王冠瑋\n郭淑芬\n陳俊霖\n曾佩珊\n蔡柏叡\n黃家瑜\n黃欣怡\n賴怡婷\n王志誠\n林志豪\n鄭佳穎\n洪建勳\n謝怡萱\n郭俊榮\n郭冠霖\n劉冠霖\n吳俊宏\n楊志瑋\n吳冠霖\n吳淑娟']

# %%
import os

relative_path = 'Lesson8/assets/names.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# /workspaces/Test_AI/Lesson8/Lesson8/assets/names.txt

# %%
import os

def get_names(file_name):

    relative_path = "assets/" + file_name
    absolute_path = os.path.abspath(relative_path)

    with open(absolute_path, 'r', encoding='utf-8') as f:
        content = f.read()

    return content.split('\n')

names = get_names("names.txt")
print(names)

print(len(names))
# Out:
# ['邱家綺', '洪思涵', '賴家恩', '周冠倫', '黃怡婷', '廖冠廷', '許惠如', '楊雅慧', '賴冠宇', '邱雅婷', '蔡冠廷', '黃雅筑', '張惠如', '許淑華', '黃佩珊', '賴欣樺', '洪俊榮', '郭柏叡', '許佩君', '周佳蓉', '邱彥廷', '黃佳穎', '廖家豪', '邱怡君', '謝俊宇', '鄭柏均', '陳雅文', '張偉倫', '謝家瑋', '賴佩芸', '張佩雯', '曾宥嘉', '吳家瑜', '蔡俊豪', '謝雅筑', '廖佩蓉', '鄭雅慧', '許俊毅', '林佩珊', '郭雅筑', '王志誠', '李俊維', '鄭惠如', '楊宥嘉', '邱冠中', '許佩蓉', '王俊維', '吳佳穎', '謝俊宏', '王欣穎', '鄭雅筑', '謝俊偉', '蔡志偉', '蔡欣樺', '王建宏', '楊志豪', '廖俊偉', '郭雅雯', '廖志偉', '謝淑娟', '洪冠霖', '許家恩', '張冠倫', '曾美玲', '謝雅婷', '曾冠瑋', '郭志偉', '許怡樺', '廖志明', '陳俊傑', '邱俊霖', '鄭家綸', '王俊榮', '楊嘉欣', '蔡俊宏', '黃家瑋', '黃佩雯', '許雅文', '洪志偉', '王怡婷', '王冠瑋', '郭淑芬', '陳俊霖', '曾佩珊', '蔡柏叡', '黃家瑜', '黃欣怡', '賴怡婷', '王志誠', '林志豪', '鄭佳穎', '洪建勳', '謝怡萱', '郭俊榮', '郭冠霖', '劉冠霖', '吳俊宏', '楊志瑋', '吳冠霖', '吳淑娟']
# 100

# %%
import random

Names_random5 = random.sample(names, 5)

for name in Names_random5:
    print(name)
# Out:
# 林佩珊
# 郭柏叡
# 謝雅筑
# 曾美玲
# 蔡欣樺

# %%
#dictory的建立和取出元素, key-value pair

Scores ={
    "name": "Golden",
    "國文": 95,
    "數學": 88,
    "英文": 92    
}

print(Scores["name"])
print(Scores["國文"])
print(Scores["數學"])
print(Scores["英文"])
# Out:
# Golden
# 95
# 88
# 92

# %%
import random

Names_random5 = random.sample(names, 5)

for name in Names_random5:
    info = {"姓名": name,
            "國文": random.randint(60, 100),
            "數學": random.randint(60, 100),
            "英文": random.randint(60, 100)
           }
    print(info)
# Out:
# {'姓名': '鄭雅慧', '國文': 78, '數學': 61, '英文': 94}
# {'姓名': '黃佳穎', '國文': 66, '數學': 80, '英文': 72}
# {'姓名': '黃佩珊', '國文': 97, '數學': 100, '英文': 74}
# {'姓名': '蔡柏叡', '國文': 90, '數學': 60, '英文': 82}
# {'姓名': '廖志偉', '國文': 81, '數學': 68, '英文': 100}

# %%
#建立一個包含5個學生資料的list，每個學生資料為一個dictory

import random

Names_random5 = random.sample(names, 5)
scores_list = []
for name in Names_random5:
    info = {"姓名": name,
            "國文": random.randint(60, 100),
            "數學": random.randint(60, 100),
            "英文": random.randint(60, 100)
           }
    scores_list.append(info)

scores_list
# Out:
# [{'姓名': '蔡志偉', '國文': 97, '數學': 67, '英文': 90},
#  {'姓名': '洪俊榮', '國文': 82, '數學': 86, '英文': 97},
#  {'姓名': '吳淑娟', '國文': 60, '數學': 74, '英文': 81},
#  {'姓名': '黃佩雯', '國文': 84, '數學': 92, '英文': 89},
#  {'姓名': '廖俊偉', '國文': 90, '數學': 62, '英文': 96}]

# %%
import random

def generate_student_scores(names, num=10):
    Names_randomN = random.sample(names, num)
    scores_list = []
    for name in Names_randomN:
        info = {"姓名": name,
                "國文": random.randint(60, 100),
                "數學": random.randint(60, 100),
                "英文": random.randint(60, 100)
            }
        scores_list.append(info)                        
    return scores_list

student_scroes = generate_student_scores(names,5)
student_scroes
# Out:
# [{'姓名': '廖佩蓉', '國文': 86, '數學': 91, '英文': 72},
#  {'姓名': '楊宥嘉', '國文': 68, '數學': 71, '英文': 95},
#  {'姓名': '邱俊霖', '國文': 77, '數學': 81, '英文': 68},
#  {'姓名': '許惠如', '國文': 89, '數學': 73, '英文': 71},
#  {'姓名': '吳佳穎', '國文': 94, '數學': 100, '英文': 78}]
