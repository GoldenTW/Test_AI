# %%
from dotenv import load_dotenv
import os
load_dotenv()
#os.environ.get("GEMINI_API_KEY")
API_key = os.environ["GEMINI_API_KEY"]
print(API_key)
# Out:
# AIzaSyAI0CoH5y2af6pyZ8JSnVV-NszFLQbPvO0

# %%
from google import genai
from dotenv import load_dotenv
import os
load_dotenv()

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

response = client.models.generate_content( model="gemini-2.5-flash", contents="請說一則2026/1/30的新聞")

print(response.text)
# Out:
# 好的，以下是一則您要求的2026年1月30日新聞報導：
#
# ---
#
# **[國際頭條] 全球AI治理峰會閉幕：數位主權與創新天秤兩端拉鋸，未來挑戰浮現**
#
# **發稿日期：2026年1月30日**
#
# **[瑞士達沃斯訊]** 為期三天的全球人工智慧（AI）治理峰會於今日在瑞士達沃斯閉幕。儘管各國代表、科技巨頭領袖與倫理專家在多數基礎性AI倫理準則上達成初步共識，但關於「數位主權」與國際AI技術共享的議題，各方仍存在顯著分歧，凸顯出全球在形塑AI未來發展軌跡上的艱鉅挑戰。
#
# 本次峰會由聯合國發起，旨在應對AI技術快速迭代所帶來的潛在風險，包括深化社會不平等、訊息操縱、自主武器的倫理困境，以及對全球就業市場的衝擊。會議期間，各國就AI模型開發的透明度、資料隱私保護、可解釋性（Explainability）以及防範偏見等關鍵原則進行了深入討論，並最終在一份不具約束力的《達沃斯AI倫理宣言》草案中，納入保護人權、促進公平使用和確保人類監督等核心價值。
#
# 然而，峰會的焦點很快便轉向了日益緊張的「數位主權」議題。多個國家，特別是新興經濟體，強烈主張應擁有對其境內AI技術和數據的絕對控制權，並擔憂過度依賴少數大型科技公司的AI模型，恐將削弱國家自主發展能力和國家安全。他們呼籲建立更加分散、多中心化的AI生態系統，並探討限制跨國AI模型對本國數據的存取權限。
#
# 另一方面，以美國、歐盟為首的部分國家與科技企業則強調，AI的本質是全球性的，過度強調數位主權將阻礙技術創新與普惠應用。他們認為，封閉的AI生態系統不僅會減緩研發速度，更可能導致各國重複投資，最終未能有效利用AI解決氣候變遷、醫療保健等全球性挑戰。
#
# 聯合國秘書長在閉幕記者會上表示：「本次峰會證明，國際社會已深刻意識到AI治理的緊迫性。儘管我們在某些領域取得了進展，但在數位主權和國際合作的平衡點上，我們仍有漫長且充滿挑戰的道路要走。我們必須找到一種模式，既能激發AI的無限潛力，又能確保其發展符合全人類的福祉。」
#
# 分析人士指出，本次峰會的結果預示著2026年全球AI發展將進入一個更加複雜的階段。各國可能會加速推動本國的AI戰略和法規，並可能出現更多針對特定AI技術和數據流動的貿易壁壘。未來的國際協商，將需要更多智慧來化解各國在國家利益與人類共同未來之間的矛盾。
#
# ---
