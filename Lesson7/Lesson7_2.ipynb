# %%
cities = []
print(type(cities))
print(cities)
# Out:
# <class 'list'>
# []

# %%
cities = []
print(type(cities))
print(cities)
cities.append("Taipei")
cities.append("New York")
cities.append("Tokyo")
print(cities)

cities.insert(1, "London")
print(cities)
# Out:
# <class 'list'>
# []
# ['Taipei', 'New York', 'Tokyo']
# ['Taipei', 'London', 'New York', 'Tokyo']
