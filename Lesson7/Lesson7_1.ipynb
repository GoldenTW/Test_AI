# %%
city1 = '台北'
city2 = '台中'
city3 = '高雄'

print(city1, city2, city3)
# Out:
# 台北 台中 高雄

# %%
# [] 建立List

cities = ['台北', '台中', '高雄']
print(cities)
print(cities[0])
print(cities[1])
print(cities[2])
# Out:
# ['台北', '台中', '高雄']
# 台北
# 台中
# 高雄

# %%
#[]建立list

Greetings = list("Hello! World ")
print(Greetings)
print(type(Greetings))
print(Greetings[0])
print(Greetings[7])
# Out:
# ['H', 'e', 'l', 'l', 'o', '!', ' ', 'W', 'o', 'r', 'l', 'd', ' ']
# <class 'list'>
# H
# W
