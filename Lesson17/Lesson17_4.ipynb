# %%
import pandas as pd
s = pd.Series([20,21,12],index=["Landon","New York","Helsinki"])
s.apply(lambda x: x**2)
# Out:
# Landon      400
# New York    441
# Helsinki    144
# dtype: int64

# %%
def add_value(x,a):
    return x**a

s.apply(add_value,args=(2,))
# Out:
# Landon      400
# New York    441
# Helsinki    144
# dtype: int64
