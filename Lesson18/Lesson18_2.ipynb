# %%
import os

#取得目前工作目錄
current_working_directory = os.getcwd()
print("目前工作目錄:", current_working_directory)

#取得該目錄下'data'資料夾內'每日各站進出人數2020.csv'檔案的完整路徑
data_file_path = os.path.join(current_working_directory, 'data', '每日各站進出人數2020.csv')
print("資料檔案完整路徑:", data_file_path)
# Out:
# 目前工作目錄: /Users/golden/Desktop/AI分析/Python/Test_AI/Lesson18
# 資料檔案完整路徑: /Users/golden/Desktop/AI分析/Python/Test_AI/Lesson18/data/每日各站進出人數2020.csv
