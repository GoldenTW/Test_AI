# %%
print('Hello! World.')
# Out:
# Hello! World.

# %%
import requests

# %%
import requests
from requests import JSONDecodeError

try:
    url = "https://example.com"
    response = requests.get(url)
    print(response.status_code)   # HTTP 狀態碼
    print(response.text)          # 回傳字串
    print(response.json())        # 若內容為 JSON
except JSONDecodeError:
    print("內容不是JSON的格式")
except Exception:
    pritn("發生錯誤")
else:
    print("沒有錯誤")
# Out:
# 200
# <!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>
#
# 內容不是JSON的格式

# %%
import requests
from requests import HTTPError,JSONDecodeError

try: 
    url = "https://data.moenv.gov.tw/api/v2/aqf_p_01?api_key=e75b1660-e564-4107-aad5-a8be1f905dd9&limit=1000&sort=publishtime%20desc&format=JSON"
    response = requests.get(url,verify=False)
    response.raise_for_status()
    data_dict:dict = response.json()
    data_list:list = data_dict['fields']
    for item in data_list:
        print(item)
except HTTPError as e:
    print(f"HTTPError:{e}")
except JSONDecodeError:
    print("內容不是JSON的格式")
except Exception:
    print("不知明錯誤")
else:
    print("下載成功")
# Out:
# /opt/conda/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.moenv.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'id': 'content', 'type': 'text', 'info': {'label': '預報文字'}}
# {'id': 'publishtime', 'type': 'text', 'info': {'label': '發布時間'}}
# {'id': 'area', 'type': 'text', 'info': {'label': '空品區名稱'}}
# {'id': 'majorpollutant', 'type': 'text', 'info': {'label': '主要污染物名稱'}}
# {'id': 'forecastdate', 'type': 'text', 'info': {'label': '預報日期'}}
# {'id': 'aqi', 'type': 'text', 'info': {'label': '空氣品質指標預報值'}}
# {'id': 'minorpollutant', 'type': 'text', 'info': {'label': '次要污染物名稱'}}
# {'id': 'minorpollutantaqi', 'type': 'text', 'info': {'label': '次要污染物指標預報值'}}
# 下載成功
